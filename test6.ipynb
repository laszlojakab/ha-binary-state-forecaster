# %%
from custom_components.discrete_state_forecaster.model.temporal.temporal_feature import TemporalFeature
from custom_components.discrete_state_forecaster.model.temporal.time_key import TimeKey

# %%
x = TemporalFeature("test", 55)
# Out:
# test = 56, test = 55

# %%
from dataclasses import asdict
asdict(TimeKey.from_temporal_feature(TemporalFeature("test", 56)) + x)
# Out:
# {'parent': {'parent': {'parent': None, 'feature': None},
#   'feature': {'name': 'test', 'value': 56}},
#  'feature': {'name': 'test', 'value': 55}}
