# %%
from custom_components.discrete_state_forecaster.model.forecaster_engine import (
    ForecasterEngine,
)
from custom_components.discrete_state_forecaster.model.temporal.time_key import TimeKey

engine = ForecasterEngine(half_life=100000000)
# |--------------------|---------------------|---------------------|---------------------->
# 0        on          10       on          20        off         30        off
#
engine.update(TimeKey.GLOBAL, state="on", timestamp=0)
engine.update(TimeKey.GLOBAL, state="on", timestamp=10) # 10 on
engine.update(TimeKey.GLOBAL, state="off", timestamp=20) # 10 off
engine.update(TimeKey.GLOBAL, state="off", timestamp=30) # 20 off
engine.update(TimeKey.GLOBAL, state="off", timestamp=40) # 30 off
engine.update(TimeKey.GLOBAL, state="on", timestamp=3600) # 40 off
# engine.update(TimeKey.GLOBAL, state="off", timestamp=3600.0 * 11)
# engine.update(TimeKey.GLOBAL, state="off", timestamp=3600.0 * 12)
# engine.update(TimeKey.GLOBAL, state="off", timestamp=3600.0 * 13)
# engine.update(TimeKey.GLOBAL, state="off", timestamp=3600.0 * 14)
# engine.update(TimeKey.GLOBAL, state="off", timestamp=3600.0 * 15)
pred = engine.predict(TimeKey.GLOBAL)
pred2 = engine.predict_with_persistence(TimeKey.GLOBAL)

if pred is not None:
    print(pred.key, pred.contributions, pred.distribution.distribution())

if pred2 is not None:
    print(pred2.key, pred2.contributions, pred2.distribution.distribution())

# print(engine.is_drifting)
print(engine._drift_monitor._slow_baseline.distribution())
print(engine._drift_monitor._fast_baseline.distribution())


engine._state_persistence_tracker._mean_duration
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from custom_components.discrete_state_forecaster.model.forecaster_engine import (
#       2     ForecasterEngine,
#       3 )
#       4 from custom_components.discrete_state_forecaster.model.temporal.time_key import TimeKey
#       7 engine = ForecasterEngine(half_life=100000000)
#
# File ~/code/homeassistant-binary-sensor-predictor/custom_components/discrete_state_forecaster/model/forecaster_engine.py:16
#       9 from custom_components.discrete_state_forecaster.model.learning.drift_monitor import (
#      10     DriftMonitor,
#      11     DriftMonitorHyperParameters,
#      12 )
#      13 from custom_components.discrete_state_forecaster.model.learning.hyper_parameter_controller import (
#      14     HyperParameterController,
#      15 )
# ---> 16 from custom_components.discrete_state_forecaster.model.learning.state_persistence_tracker import (
#      17     StatePersistenceTracker,
#      18     StatePersistenceTrackerHyperParameters,
#      19 )
#      20 from custom_components.discrete_state_forecaster.model.metrics.online_error_tracker import (
#      21     OnlineErrorTracker,
#      22     OnlineErrorTrackerHyperParameters,
#      23 )
#      24 from custom_components.discrete_state_forecaster.model.statistics.distribution_stats import (
#      25     DistributionStats,
#      26 )
#
# File ~/code/homeassistant-binary-sensor-predictor/custom_components/discrete_state_forecaster/model/learning/state_persistence_tracker.py:8
#       2 from typing import Final, Self
#       4 from custom_components.discrete_state_forecaster.model.state import (
#       5     State,
#       6 )
# ----> 8 from .state_persistence_tracker_hyper_parameters import (
#       9     StatePersistenceTrackerHyperParameters,
#      10 )
#      13 class StatePersistenceTracker:
#      14     def __init__(
#      15         self: Self, hyper_parameters: StatePersistenceTrackerHyperParameters
#      16     ) -> None:
#
# File ~/code/homeassistant-binary-sensor-predictor/custom_components/discrete_state_forecaster/model/learning/state_persistence_tracker_hyper_parameters.py:3
#       1 from typing import Final, Self
# ----> 3 from custom_components.discrete_state_forecaster.model.state import HyperParameters
#       6 class StatePersistenceTrackerHyperParameters:
#       7     def __init__(
#       8         self: Self,
#       9         *,
#      10         hyper_parameters: HyperParameters,
#      11         persistence_half_life_factor: float,
#      12     ) -> None:
#
# ImportError: cannot import name 'HyperParameters' from 'custom_components.discrete_state_forecaster.model.state' (/Users/laszlojakab/code/homeassistant-binary-sensor-predictor/custom_components/discrete_state_forecaster/model/state.py)
