# %%
from custom_components.discrete_state_forecaster.model.temporal.time_key import TimeKey


# calendar, day of week, month of year, season, time of day
key = TimeKey.from_tuple(
    (
        ("holiday_calendar", 1),
        ("home_office_calendar", 1),
        ("day_of_week", "mon"),
        ("month_of_year", "jan"),
        ("season", "winter"),
        ("time_of_day", 5),
    )
)

for k in key.hierarchy():
    print(k)
# Out:
# holiday_calendar = 1, home_office_calendar = 1, day_of_week = mon, month_of_year = jan, season = winter, time_of_day = 5
# holiday_calendar = 1, home_office_calendar = 1, day_of_week = mon, month_of_year = jan, season = winter
# holiday_calendar = 1, home_office_calendar = 1, day_of_week = mon, month_of_year = jan
# holiday_calendar = 1, home_office_calendar = 1, day_of_week = mon
# holiday_calendar = 1, home_office_calendar = 1
# holiday_calendar = 1
# GLOBAL
